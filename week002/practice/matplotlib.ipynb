# %% [markdown]
# # matplotlib excersise
# 表示されている画像と同様のグラウを表示してください。
# グラフ中に表示されているデータの値の内容は問いません。

# %% [markdown]
# ### 1. matplotlib のグラフをインラインで表示 & import

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### 2. y = a * x + bをプロット
# ![](fig/fig02.png)

# %%
x = np.linspace(0,9,10)
y = 2*x - 1
plt.plot(x,y,"r-")
ｐｌｔ.xlim([0,9])
plt.ylim([-5,20])
plt.show()

# %% [markdown]
# ### 3. 散布図をプロット
# ![](fig/fig03.png)

# %%
x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x,y)

# %% [markdown]
# ### 4. ヒストグラムをプロット
# ![](fig/fig04.png)

# %%
x = np.random.rand(100)
plt.hist(x)
# Out:
# (array([ 12.,  11.,  16.,   7.,  11.,   9.,   3.,   8.,  10.,  13.]),
#  array([  8.18252073e-04,   1.00482813e-01,   2.00147374e-01,
#           2.99811936e-01,   3.99476497e-01,   4.99141058e-01,
#           5.98805619e-01,   6.98470180e-01,   7.98134741e-01,
#           8.97799302e-01,   9.97463864e-01]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### 5. y = a * x**2 + b * x + cをプロット - 凡例を入れてみる
# ![](fig/fig05.png)

# %%
x = np.arange(0,9,0.01) 
y = 2 * x**2 - x + 1
plt.plot(x,y, label='2*x^2 - x + 1', marker='o', markevery = 100) 
plt.legend()
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('TITLE')
ｐｌｔ.xlim([0,9])
plt.ylim([0,160])
plt.show()

# %% [markdown]
# ### 6. y = a * x**2 + b * x + cをプロット
#  + 凡例の場所調整
#  + プロットの点、色を変更
#  + 背景を格子に変更
#
#  ![](fig/fig06.png)

# %%
x = np.arange(0,9,0.01) 
y = 2 * x**2 - x + 1
plt.plot(x,y, label='2*x^2 - x + 1', marker='^', markevery = 100, color = 'r') 
plt.legend(loc='lower center') 
plt.grid(which='major',color='black',linestyle='-')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('TITLE')
ｐｌｔ.xlim([0,9])
plt.ylim([0,160])
plt.show()

# %% [markdown]
# ### 7. y = a * x**2 + b * x + cをプロット - 縦軸/横軸の調整
# ![](fig/fig07.png)

# %%
x = np.arange(0,10,0.01) 
y = 2 * x**2 - x + 1
plt.plot(x,y, label='2*x^2 - x + 1', marker='o', markevery = 100, color = 'b') 
plt.legend()
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('TITLE')
ｐｌｔ.xlim([0,10])
#ｐｌｔ.ylim([0,100])
plt.yscale('log')
plt.show()

# %% [markdown]
# ### 8. y = a x**2 + b x + cにエラーバーを追加
# ![](fig/fig08.png)

# %%
x = np.arange(0,10,1) 
y = 2 * x**2 - x + 1
plt.errorbar(x, y, 10*np.ones(len(x)), np.ones(len(y)), color="g", label = "y = 2*x^2 - x +1 (sigma_x = 10, sigma_y = 1)")
plt.legend(loc='upper center') 
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('TITLE')
ｐｌｔ.xlim([0,10])
plt.yscale('log')
plt.show()

# %% [markdown]
# ### 9. 散布図をカスタム
#  + サイズ
#  + 色 (マーカーの中&縁を別色)
#  + 不透明度
#  + 線のサイズ
#  + マーカー
#  ![](fig/fig09.png)

# %%
x = np.random.rand(100)
y = np.random.rand(100)
plt.scatter(x, y, s=600, c='pink',  alpha=0.5, linewidths="2",
            edgecolors='r', marker="*")

# %% [markdown]
# ### 10.  3次元散布図をプロット
# ![](fig/fig10.png)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")

ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
ax.set_zlim(-1, 1)
x = np.random.rand(100) * 2 - 1
y = np.random.rand(100) * 2 - 1
z = np.random.rand(100) * 2 - 1
ax.scatter3D(x, y, z, color="pink", linewidths="2", edgecolors="red", marker="*")

# %% [markdown]
# ## ここからかっこいいやつ
# サンプルの図と似たグラフを書ければいいです。
# ## 3D編

# %% [markdown]
# ### 11. ワイヤーフレームの作成
# ![](fig/fig11.png)

# %%
x = np.arange(-3, 3, 0.25)
y = np.arange(-3, 3, 0.25)
X, Y = np.meshgrid(x, y)
Z = np.sin(X)+ np.cos(Y)

fig = plt.figure()
ax = Axes3D(fig)
ax.plot_wireframe(X,Y,Z) #<---ここでplot

plt.show()

# %% [markdown]
# ### 12. 色付きワイヤーフレーム (サーフェイス)
# ![](fig/fig12.png)

# %%
from matplotlib import cm
x = np.arange(-3, 3, 0.25)
y = np.arange(-3, 3, 0.25)
X, Y = np.meshgrid(x, y)
Z = np.sin(X)+ np.cos(Y)

fig = plt.figure()
ax = Axes3D(fig)
surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm)

fig.colorbar(surf)
ax.set_title("Surface Plot")

# %% [markdown]
# ### 13. 等高線をプロット
# ![](fig/fig13.png)

# %%
from matplotlib import cm
x = np.arange(-3, 3, 0.25)
y = np.arange(-3, 3, 0.25)
X, Y = np.meshgrid(x, y)
Z = np.sin(X)+ np.cos(Y)

fig = plt.figure()
ax = Axes3D(fig)
surf = ax.contour(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm)

fig.colorbar(surf)
ax.set_title("Surface Plot")

# %% [markdown]
# ### 14. Scatter & Fitting curve
# ![](fig/fig14.png)

# %%
x = np.linspace(0, 2*np.pi, 50)
y = np.sin(x)
y2 = y + 0.1 * np.random.normal(size=x.shape)

fig, ax = plt.subplots()
ax.plot(x, y, 'k--')
ax.plot(x, y2, 'ro')

# set ticks and tick labels
ax.set_xlim((0, 2*np.pi))
ax.set_xticks([0, np.pi, 2*np.pi])
ax.set_xticklabels(['0', '$\pi$', '2$\pi$'])
ax.set_ylim((-1.5, 1.5))
ax.set_yticks([-1, 0, 1])

# Only draw spine between the y-ticks
ax.spines['left'].set_bounds(-1, 1)
# Hide the right and top spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
# Only show ticks on the left and bottom spines
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

# %% [markdown]
# ### 15. 温度分布 (複数グラフ)
# ![](fig/fig15.png)

# %%
import matplotlib.colors as mcolors
import numpy as np
from numpy.random import multivariate_normal

data = np.vstack([
    multivariate_normal([10, 10], [[3, 2], [2, 3]], size=100000),
    multivariate_normal([30, 20], [[2, 3], [1, 3]], size=1000)
])

gammas = [0.8, 0.5, 0.3]

fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0, 0].set_title('Linear normalization')
axes[0, 0].hist2d(data[:, 0], data[:, 1], bins=100)

for ax, gamma in zip(axes.flat[1:], gammas):
    ax.set_title('Power law $(\gamma=%1.1f)$' % gamma)
    ax.hist2d(data[:, 0], data[:, 1],
              bins=100, norm=mcolors.PowerNorm(gamma))

fig.tight_layout()

# %% [markdown]
# ### 16. バーチャート
# ![](fig/fig16.png)

# %%
n_groups = 5

means_men = (20, 35, 30, 35, 27)
std_men = (2, 3, 4, 1, 2)

means_women = (25, 32, 34, 20, 25)
std_women = (3, 5, 2, 3, 3)

fig, ax = plt.subplots()

index = np.arange(n_groups)
bar_width = 0.35

opacity = 0.4
error_config = {'ecolor': '0.3'}

rects1 = plt.bar(index, means_men, bar_width,
                 alpha=opacity,
                 color='b',
                 yerr=std_men,
                 error_kw=error_config,
                 label='Men')

rects2 = plt.bar(index + bar_width, means_women, bar_width,
                 alpha=opacity,
                 color='r',
                 yerr=std_women,
                 error_kw=error_config,
                 label='Women')

plt.xlabel('Group')
plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(index + bar_width / 2, ('A', 'B', 'C', 'D', 'E'))
plt.legend()

plt.tight_layout()

# %% [markdown]
# ### 17. matplotlib logo
# ![](fig/fig17.png)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.cm as cm

mpl.rcParams['xtick.labelsize'] = 10
mpl.rcParams['ytick.labelsize'] = 12
mpl.rcParams['axes.edgecolor'] = 'gray'


axalpha = 0.05
figcolor = 'white'
dpi = 80
fig = plt.figure(figsize=(6, 1.1), dpi=dpi)
fig.figurePatch.set_edgecolor(figcolor)
fig.figurePatch.set_facecolor(figcolor)


def add_math_background():
    ax = fig.add_axes([0., 0., 1., 1.])

    text = []
    text.append(
        (r"$W^{3\beta}_{\delta_1 \rho_1 \sigma_2} = "
         r"U^{3\beta}_{\delta_1 \rho_1} + \frac{1}{8 \pi 2}"
         r"\int^{\alpha_2}_{\alpha_2} d \alpha^\prime_2 "
         r"\left[\frac{ U^{2\beta}_{\delta_1 \rho_1} - "
         r"\alpha^\prime_2U^{1\beta}_{\rho_1 \sigma_2} "
         r"}{U^{0\beta}_{\rho_1 \sigma_2}}\right]$", (0.7, 0.2), 20))
    text.append((r"$\frac{d\rho}{d t} + \rho \vec{v}\cdot\nabla\vec{v} "
                 r"= -\nabla p + \mu\nabla^2 \vec{v} + \rho \vec{g}$",
                 (0.35, 0.9), 20))
    text.append((r"$\int_{-\infty}^\infty e^{-x^2}dx=\sqrt{\pi}$",
                 (0.15, 0.3), 25))
    text.append((r"$F_G = G\frac{m_1m_2}{r^2}$",
                 (0.85, 0.7), 30))
    for eq, (x, y), size in text:
        ax.text(x, y, eq, ha='center', va='center', color="#11557c",
                alpha=0.25, transform=ax.transAxes, fontsize=size)
    ax.set_axis_off()
    return ax


def add_matplotlib_text(ax):
    ax.text(0.95, 0.5, 'matplotlib', color='#11557c', fontsize=65,
            ha='right', va='center', alpha=1.0, transform=ax.transAxes)


def add_polar_bar():
    ax = fig.add_axes([0.025, 0.075, 0.2, 0.85], projection='polar')

    ax.axesPatch.set_alpha(axalpha)
    ax.set_axisbelow(True)
    N = 7
    arc = 2. * np.pi
    theta = np.arange(0.0, arc, arc/N)
    radii = 10 * np.array([0.2, 0.6, 0.8, 0.7, 0.4, 0.5, 0.8])
    width = np.pi / 4 * np.array([0.4, 0.4, 0.6, 0.8, 0.2, 0.5, 0.3])
    bars = ax.bar(theta, radii, width=width, bottom=0.0)
    for r, bar in zip(radii, bars):
        bar.set_facecolor(cm.jet(r/10.))
        bar.set_alpha(0.6)

    for label in ax.get_xticklabels() + ax.get_yticklabels():
        label.set_visible(False)

    for line in ax.get_ygridlines() + ax.get_xgridlines():
        line.set_lw(0.8)
        line.set_alpha(0.9)
        line.set_ls('-')
        line.set_color('0.5')

    ax.set_yticks(np.arange(1, 9, 2))
    ax.set_rmax(9)


main_axes = add_math_background()
add_polar_bar()
add_matplotlib_text(main_axes)
